# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Set path to your data folder in Google Drive
# Example: '/content/drive/MyDrive/Spatial_GNN/3.InputML'
DRIVE_PATH = '/content/drive/MyDrive/Spatial GNN/model'
INPUT_DIR = f"{DRIVE_PATH}/3.InputML"
OUTPUT_DIR = f"{DRIVE_PATH}/5.OutputML_GAT_4CLASS"

print(f"Data path: {INPUT_DIR}")
print(f"Output path: {OUTPUT_DIR}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Data path: /content/drive/MyDrive/Spatial GNN/model/3.InputML
# Output path: /content/drive/MyDrive/Spatial GNN/model/5.OutputML_GAT_4CLASS

# %%
# Install required packages
# !pip install -q torch torch-geometric networkx pandas scikit-learn matplotlib seaborn
print("✓ Packages installed successfully!")
# Out:
# ✓ Packages installed successfully!

# %%
# Imports
import os
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import networkx as nx
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
from torch_geometric.loader import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import KFold, LeaveOneOut
from sklearn.metrics import (
    precision_recall_fscore_support,
    confusion_matrix,
)
import matplotlib.pyplot as plt
import seaborn as sns

# Set random seeds for reproducibility
SEED = 100
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print("✓ Imports complete")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# ✓ Imports complete
# CUDA available: True
# GPU: NVIDIA A100-SXM4-40GB

# %%
# Plotting functions
def plot_training_validation(train_losses, val_losses, save_path):
    """Plot training and validation loss curves"""
    plt.figure(figsize=(10, 6))
    plt.plot(train_losses, label='Training Loss', linewidth=2)
    plt.plot(val_losses, label='Validation Loss', linewidth=2)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.title('Training vs Validation Loss', fontsize=14)
    plt.legend(fontsize=10)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    plt.close()

def plot_validation_accuracy(accuracies, save_path):
    """Plot validation accuracy over epochs"""
    plt.figure(figsize=(10, 6))
    plt.plot(accuracies, linewidth=2, color='green')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Validation Accuracy', fontsize=12)
    plt.title('Validation Accuracy Over Time', fontsize=14)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    plt.close()

def plot_lr_schedule(lrs, save_path):
    """Plot learning rate schedule"""
    plt.figure(figsize=(10, 6))
    plt.plot(lrs, linewidth=2, color='orange')
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Learning Rate', fontsize=12)
    plt.title('Learning Rate Schedule', fontsize=14)
    plt.yscale('log')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    plt.close()

def plot_class_accuracies(y_true, y_pred, label_names, save_path):
    """Plot per-class accuracy histogram"""
    accuracies = []
    for class_id in range(len(label_names)):
        mask = y_true == class_id
        if mask.sum() > 0:
            class_acc = (y_pred[mask] == y_true[mask]).sum() / mask.sum()
            accuracies.append(class_acc)
        else:
            accuracies.append(0.0)

    plt.figure(figsize=(10, 6))
    bars = plt.bar(label_names, accuracies, color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728'])
    plt.xlabel('Class', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.title('Per-Class Accuracy', fontsize=14)
    plt.ylim(0, 1.0)

    # Add value labels on bars
    for bar, acc in zip(bars, accuracies):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height,
                f'{acc:.3f}', ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.savefig(save_path, dpi=150)
    plt.show()
    plt.close()

print("✓ Plotting functions defined")
# Out:
# ✓ Plotting functions defined

# %% [markdown]
# ## Define Model Components

# %%
# Focal Loss for handling class imbalance
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=3.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction="none")
        pt = torch.exp(-ce_loss)
        focal_weight = (1 - pt) ** self.gamma

        if self.alpha is not None:
            alpha_t = self.alpha[targets]
            focal_weight = alpha_t * focal_weight

        loss = focal_weight * ce_loss
        return loss.mean()

print("✓ Focal Loss defined")
# Out:
# ✓ Focal Loss defined

# %%
# Data augmentation
def data_augmentation(x, edge_index, training=True):
    if not training:
        return x, edge_index
    if torch.rand(1).item() < 0.2:
        x = x + torch.randn_like(x) * 0.08
    if torch.rand(1).item() < 0.1 and edge_index.shape[1] > 0:
        keep_mask = torch.rand(edge_index.shape[1]) > 0.15
        if keep_mask.sum() > 0:
            edge_index = edge_index[:, keep_mask]
    return x, edge_index

print("✓ Data augmentation defined")
# Out:
# ✓ Data augmentation defined

# %%
# Oversampling for minority classes
def oversample_minority_classes(data_list, target_ratio=0.5):
    class_counts = {0: 0, 1: 0, 2: 0, 3: 0}
    for d in data_list:
        for label in d.y:
            class_counts[label.item()] += 1

    max_count = max(class_counts.values())
    target_counts = {i: int(max_count * target_ratio) for i in range(4)}

    oversampled = list(data_list)
    for class_id in [1, 2, 3]:
        if class_counts[class_id] < target_counts[class_id]:
            graphs_with_class = [d for d in data_list if (d.y == class_id).any()]
            if not graphs_with_class:
                continue
            needed = target_counts[class_id] - class_counts[class_id]
            nodes_per_graph = sum((d.y == class_id).sum().item() for d in graphs_with_class) / len(graphs_with_class)
            duplicates_needed = max(1, int(needed / nodes_per_graph))

            for _ in range(duplicates_needed):
                for g in graphs_with_class:
                    oversampled.append(g)

    return oversampled

print("✓ Oversampling function defined")
# Out:
# ✓ Oversampling function defined

# %%
# Load GraphML data
def load_graphml_data(graphml_path):
    G = nx.read_graphml(graphml_path)

    node_features = []
    node_labels = []
    node_mapping = {}

    for i, (node_id, data) in enumerate(G.nodes(data=True)):
        node_mapping[node_id] = i
        features = []

        # Geometric features
        x = float(data.get("pos_x", 0.0))
        y = float(data.get("pos_y", 0.0))

        bb_xmin = float(data.get("bb_xmin", 0.0))
        bb_ymin = float(data.get("bb_ymin", 0.0))
        bb_zmin = float(data.get("bb_zmin", 0.0))
        bb_xmax = float(data.get("bb_xmax", 0.0))
        bb_ymax = float(data.get("bb_ymax", 0.0))
        bb_zmax = float(data.get("bb_zmax", 0.0))

        w = bb_xmax - bb_xmin if bb_xmax > bb_xmin else 1.0
        h = bb_ymax - bb_ymin if bb_ymax > bb_ymin else 1.0
        d = bb_zmax - bb_zmin if bb_zmax > bb_zmin else 1.0

        features.extend([x, y, bb_xmin, bb_ymin, bb_zmin, w, h, d])

        volume = w * h * d
        surface_area = 2 * (w * h + h * d + w * d)
        features.extend([volume, surface_area])

        features.extend([
            w / h if h else 0.0,
            h / d if d else 0.0,
            w / d if d else 0.0,
        ])

        length = float(data.get("length", 0.0))
        height = float(data.get("height", 0.0))
        thickness = float(data.get("thickness", 0.0))
        area = float(data.get("area", 0.0))
        width = float(data.get("width", 0.0))
        depth = float(data.get("depth", 0.0))
        features.extend([length, height, thickness, area, width, depth])

        element_type = data.get("element_type", "unknown")
        type_encoding = {"wall": 1, "beam": 2, "foundation": 3, "slab": 4,
                        "genericmodel": 5, "zone": 6, "level": 7, "unknown": 0}
        features.append(type_encoding.get(str(element_type).lower(), 0))

        node_features.append(features)

        label = 0
        if "label_type" in data:
            try:
                label = int(data["label_type"])
                if label not in [0, 1, 2, 3]:
                    label = 0
            except (ValueError, TypeError):
                label = 0

        node_labels.append(label)

    edge_list = []
    for src, dst in G.edges():
        if src in node_mapping and dst in node_mapping:
            edge_list.append([node_mapping[src], node_mapping[dst]])
            edge_list.append([node_mapping[dst], node_mapping[src]])

    if not edge_list:
        return None

    edge_index = torch.tensor(edge_list, dtype=torch.long).t().contiguous()
    x_tensor = torch.tensor(node_features, dtype=torch.float)
    y_tensor = torch.tensor(node_labels, dtype=torch.long)

    return Data(x=x_tensor, edge_index=edge_index, y=y_tensor)

print("✓ GraphML loader defined")
# Out:
# ✓ GraphML loader defined

# %%
# GAT Model
class ImprovedGATModel(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, num_heads=8, num_classes=4, dropout=0.3):
        super().__init__()
        self.gat1 = GATConv(input_dim, hidden_dim // num_heads, heads=num_heads,
                            dropout=dropout, concat=True)
        self.gat2 = GATConv(hidden_dim, hidden_dim // num_heads, heads=num_heads,
                            dropout=dropout, concat=True)
        self.gat3 = GATConv(hidden_dim, hidden_dim // num_heads, heads=num_heads,
                            dropout=dropout, concat=True)
        self.gat4 = GATConv(hidden_dim, hidden_dim // 2, heads=num_heads // 2,
                            dropout=dropout, concat=True)

        self.ln1 = nn.LayerNorm(hidden_dim)
        self.ln2 = nn.LayerNorm(hidden_dim)
        self.ln3 = nn.LayerNorm(hidden_dim)
        self.ln4 = nn.LayerNorm((hidden_dim // 2) * (num_heads // 2))

        final_dim = (hidden_dim // 2) * (num_heads // 2)
        self.classifier = nn.Sequential(
            nn.Linear(final_dim, final_dim // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(final_dim // 2, num_classes),
        )
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, edge_index, batch=None):
        x = self.dropout(self.ln1(F.elu(self.gat1(x, edge_index))))
        x = self.dropout(self.ln2(F.elu(self.gat2(x, edge_index))))
        x = self.dropout(self.ln3(F.elu(self.gat3(x, edge_index))))
        x = self.ln4(F.elu(self.gat4(x, edge_index)))
        return self.classifier(x)

print("✓ GAT Model defined")
# Out:
# ✓ GAT Model defined

# %%
# Training and evaluation functions
def train_epoch(model, optimizer, criterion, loader, device):
    model.train()
    total_loss, total_correct, total_samples = 0.0, 0, 0
    for data in loader:
        data = data.to(device)
        optimizer.zero_grad()
        x_aug, edge_aug = data_augmentation(data.x, data.edge_index, training=True)
        out = model(x_aug, edge_aug)
        loss = criterion(out, data.y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        total_loss += loss.item()
        pred = out.argmax(dim=1)
        total_correct += (pred == data.y).sum().item()
        total_samples += data.y.size(0)

    return total_loss / len(loader), total_correct / total_samples


def evaluate(model, criterion, loader, device):
    model.eval()
    total_loss, total_correct, total_samples = 0.0, 0, 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            out = model(data.x, data.edge_index)
            loss = criterion(out, data.y)
            total_loss += loss.item()
            pred = out.argmax(dim=1)
            total_correct += (pred == data.y).sum().item()
            total_samples += data.y.size(0)
            all_preds.extend(pred.cpu().numpy())
            all_labels.extend(data.y.cpu().numpy())

    acc = total_correct / total_samples if total_samples else 0.0
    return acc, total_loss / len(loader), all_preds, all_labels

print("✓ Training functions defined")
# Out:
# ✓ Training functions defined

# %%
# Check what folders exist
import os
print("Checking Drive structure...")
print(f"Spatial_GNN exists: {os.path.exists('/content/drive/MyDrive/Spatial GNN')}")
print(f"model folder exists: {os.path.exists('/content/drive/MyDrive/Spatial GNN/model')}")
print(f"3.InputML exists: {os.path.exists('/content/drive/MyDrive/Spatial GNN/model/3.InputML')}")

# List what's actually there
if os.path.exists('/content/drive/MyDrive/Spatial GNN/model'):
    print(f"\nContents of model/: {os.listdir('/content/drive/MyDrive/Spatial GNN/model')}")
# Out:
# Checking Drive structure...
# Spatial_GNN exists: True
# model folder exists: True
# 3.InputML exists: True
#
# Contents of model/: ['GAT_4class_Colab.ipynb', '5.OutputML_GAT_4CLASS', '3.InputML', 'visualize_graph.py', 'GAT_text2.py', 'batch_combined_inference.py', 'run_inference_from_csv.py', 'combined_inference.py', 'run_ppvc_inference_from_csv.bat', 'map_text_to_elements.py', 'fix_annotation_csv.py', 'inspect_annotation.py', 'GAT_first_model.py', 'csv_to_graphml.py', 'GAT_4class_model.py', '5.OutputML_GAT_DIM 1', '5.OutputML_GAT_TEXT 2 OLD', '5.OutputML_GAT_DIM_OLD', '5.OutputML_GAT_DIM', '.git', '5.OutputML_GAT_NOANNOTATION VS YES', '5.OutputML_GAT_DIM 2', '5.OutputML_GAT', '5.OutputML_GAT_TEXT 1 OLD', '__pycache__', '5.OutputML_GAT_4CLASS 1st try']

# %% [markdown]
# ## Load Data

# %%
# Copy data to local storage for faster training (avoids slow Google Drive I/O)
import shutil

# Save original Drive paths
DRIVE_INPUT = INPUT_DIR
DRIVE_OUTPUT = OUTPUT_DIR

# Set up local paths
LOCAL_INPUT = '/content/data_local'
LOCAL_OUTPUT = '/content/output_local'

# Copy GraphML files to local storage if not already there
if not os.path.exists(LOCAL_INPUT):
    print(f"Copying data to local storage for faster I/O...")
    shutil.copytree(DRIVE_INPUT, LOCAL_INPUT)
    print(f"✓ Data copied to: {LOCAL_INPUT}")
else:
    print(f"✓ Using existing local data: {LOCAL_INPUT}")

# Update paths to use local storage during training
INPUT_DIR = LOCAL_INPUT
OUTPUT_DIR = LOCAL_OUTPUT
os.makedirs(OUTPUT_DIR, exist_ok=True)

print(f"\nTraining will use local storage (5-10x faster!)")
print(f"   Input:  {INPUT_DIR}")
print(f"   Output: {OUTPUT_DIR}")
print(f"   Results will be copied back to Drive at the end")
# Out:
# Copying data to local storage for faster I/O...
# ✓ Data copied to: /content/data_local
#
# Training will use local storage (5-10x faster!)
#    Input:  /content/data_local
#    Output: /content/output_local
#    Results will be copied back to Drive at the end

# %%
# Load GraphML files

graphml_files = sorted(
    [os.path.join(INPUT_DIR, f) for f in os.listdir(INPUT_DIR) if f.endswith(".graphml")]
)

if len(graphml_files) < 2:
    raise ValueError(f"Need at least 2 graphml files. Found {len(graphml_files)} in {INPUT_DIR}")

print(f"Loading {len(graphml_files)} GraphML files from {INPUT_DIR}...")
data_list = []
for fp in graphml_files:
    d = load_graphml_data(fp)
    if d is not None:
        data_list.append(d)

if len(data_list) < 2:
    raise ValueError(f"Parsed fewer than 2 valid graphs. Got {len(data_list)}")

print(f"✓ Loaded {len(data_list)} graphs successfully")
# Out:
# Loading 27 GraphML files from /content/data_local...
# ✓ Loaded 27 graphs successfully

# %%
# Dataset statistics
total_nodes = sum(len(d.y) for d in data_list)
class_counts = {0: 0, 1: 0, 2: 0, 3: 0}
for d in data_list:
    for label in d.y:
        class_counts[label.item()] += 1

print(f"\nDataset Statistics:")
print(f"  Total nodes: {total_nodes}")
print(f"  Class 0 (No Annotation): {class_counts[0]} ({100*class_counts[0]/total_nodes:.1f}%)")
print(f"  Class 1 (Dimension): {class_counts[1]} ({100*class_counts[1]/total_nodes:.1f}%)")
print(f"  Class 2 (Text): {class_counts[2]} ({100*class_counts[2]/total_nodes:.1f}%)")
print(f"  Class 3 (Both): {class_counts[3]} ({100*class_counts[3]/total_nodes:.1f}%)")

# Calculate class weights
class_weights = torch.zeros(4)
for i in range(4):
    if class_counts[i] > 0:
        freq = class_counts[i] / total_nodes
        class_weights[i] = (1.0 / freq) ** 1.5 / 4.0
    else:
        class_weights[i] = 1.0
class_weights = class_weights / class_weights.sum() * 4.0
print(f"\nClass weights: {class_weights.tolist()}")

input_dim = data_list[0].x.shape[1]
output_dim = 4
label_names = ["No Annotation", "Dimension", "Text", "Both"]

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\nUsing device: {device}")
# Out:
# Dataset Statistics:
#   Total nodes: 2433
#   Class 0 (No Annotation): 1663 (68.4%)
#   Class 1 (Dimension): 376 (15.5%)
#   Class 2 (Text): 299 (12.3%)
#   Class 3 (Both): 95 (3.9%)
#
# Class weights: [0.041382476687431335, 0.3849223256111145, 0.5428102612495422, 3.0308849811553955]
#
# Using device: cuda

# %% [markdown]
# ## Train Model with Cross-Validation

# %%
# Cross-validation with best checkpoint saving
splitter = KFold(n_splits=5, shuffle=True, random_state=SEED) if len(data_list) >= 5 else LeaveOneOut()
cv_name = "5-fold" if isinstance(splitter, KFold) else "leave-one-out"
print(f"Cross-validation: {cv_name}\n")

fold_accuracies = []
fold_f1_scores = []
all_y_true, all_y_pred = [], []
best_fold_f1, best_state = -1, None

for fold, (train_idx, test_idx) in enumerate(splitter.split(data_list), start=1):
    print(f"\n{'='*60}")
    print(f"  Fold {fold}/{splitter.get_n_splits(data_list)}")
    print(f"{'='*60}")
    fold_dir = os.path.join(OUTPUT_DIR, f"fold_{fold}")
    os.makedirs(fold_dir, exist_ok=True)

    train_data = [data_list[i] for i in train_idx]
    test_data = [data_list[i] for i in test_idx]

    # REDUCED oversampling - too much causes overfitting to minority classes
    train_data_oversampled = oversample_minority_classes(train_data, target_ratio=0.25)
    print(f"  Training: {len(train_data)} graphs -> {len(train_data_oversampled)} after oversampling")
    
    # Smaller batch size for better gradient diversity
    train_loader = DataLoader(train_data_oversampled, batch_size=16, shuffle=True)
    test_loader = DataLoader(test_data, batch_size=16, shuffle=False)

    model = ImprovedGATModel(
        input_dim=input_dim, hidden_dim=128, num_heads=8,
        num_classes=output_dim, dropout=0.4  # INCREASED dropout
    ).to(device)
    
    # REDUCED focal loss gamma - less aggressive focusing on hard examples
    criterion = FocalLoss(alpha=class_weights.to(device), gamma=1.5)
    # INCREASED weight decay for better regularization
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.002, weight_decay=0.03)
    # Schedule based on F1, not loss
    scheduler = ReduceLROnPlateau(optimizer, mode="max", factor=0.7, patience=25)

    best_val_f1, best_val_acc, best_epoch, patience_ctr, patience = 0.0, 0.0, 0, 0, 80
    epochs = 300
    train_losses, test_losses, test_accuracies, test_f1s, lrs = [], [], [], [], []
    
    # Save best model state for this fold
    best_fold_state = None

    for epoch in range(1, epochs + 1):
        tr_loss, tr_acc = train_epoch(model, optimizer, criterion, train_loader, device)
        te_acc, te_loss, te_preds, te_labels = evaluate(model, criterion, test_loader, device)

        # Calculate F1 for early stopping criterion (better for imbalanced data)
        if len(set(te_labels)) > 1:
            prec, rec, f1, _ = precision_recall_fscore_support(
                te_labels, te_preds, labels=range(4), average='macro', zero_division=0
            )
        else:
            prec = rec = f1 = 0.0

        train_losses.append(tr_loss)
        test_losses.append(te_loss)
        test_accuracies.append(te_acc)
        test_f1s.append(f1)
        lrs.append(optimizer.param_groups[0]["lr"])

        scheduler.step(f1)

        if epoch % 10 == 0 or epoch <= 10:
            print(
                f"Epoch {epoch:03d} | "
                f"TrainLoss={tr_loss:.4f} TrainAcc={tr_acc:.4f} | "
                f"TestLoss={te_loss:.4f} TestAcc={te_acc:.4f} | "
                f"P={prec:.3f} R={rec:.3f} F1={f1:.3f} | LR={lrs[-1]:.6f}"
            )

        # Save best model based on F1 score (better metric for imbalanced classes)
        if f1 > best_val_f1:
            best_val_f1 = f1
            best_val_acc = te_acc
            best_epoch = epoch
            best_fold_state = model.state_dict().copy()
            patience_ctr = 0
            print(f"    ✓ New best F1: {f1:.4f} (Acc: {te_acc:.4f})")
        else:
            patience_ctr += 1
        
        if patience_ctr >= patience:
            print(f"Early stopping at epoch {epoch} (best was epoch {best_epoch})")
            break

        # Plot progress every 25 epochs
        if epoch % 25 == 0:
            plot_training_validation(train_losses, test_losses, 
                                   os.path.join(fold_dir, "training_validation.png"))
            plot_validation_accuracy(test_accuracies,
                                   os.path.join(fold_dir, "validation_accuracy.png"))
            plot_lr_schedule(lrs, os.path.join(fold_dir, "lr_schedule.png"))

    # Load best checkpoint from this fold
    if best_fold_state is not None:
        model.load_state_dict(best_fold_state)
        print(f"Loaded best checkpoint from epoch {best_epoch}")
    
    # Final evaluation with best checkpoint
    te_acc_final, te_loss_final, y_pred_fold, y_true_fold = evaluate(
        model, criterion, test_loader, device
    )
    
    # Calculate final F1 and per-class metrics
    if len(set(y_true_fold)) > 1:
        final_prec, final_rec, final_f1, _ = precision_recall_fscore_support(
            y_true_fold, y_pred_fold, labels=range(4), average='macro', zero_division=0
        )
        # Calculate per-class accuracies
        per_class_acc = []
        for class_id in range(4):
            mask = np.array(y_true_fold) == class_id
            if mask.sum() > 0:
                class_acc = (np.array(y_pred_fold)[mask] == np.array(y_true_fold)[mask]).sum() / mask.sum()
                per_class_acc.append(class_acc)
            else:
                per_class_acc.append(0.0)
    else:
        final_f1 = 0.0
        per_class_acc = [0.0] * 4
    
    fold_accuracies.append(te_acc_final)
    fold_f1_scores.append(final_f1)
    all_y_true.extend(y_true_fold)
    all_y_pred.extend(y_pred_fold)

    # Save confusion matrix
    cm = confusion_matrix(y_true_fold, y_pred_fold, labels=range(output_dim))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=label_names, yticklabels=label_names)
    plt.title(f"Fold {fold} Confusion Matrix")
    plt.ylabel("True Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.savefig(os.path.join(fold_dir, "confusion_matrix.png"))
    plt.show()

    # Plot per-class accuracies for this fold
    plot_class_accuracies(
        np.array(y_true_fold), np.array(y_pred_fold), label_names,
        os.path.join(fold_dir, "class_accuracies_histogram.png")
    )

    # Save best model based on F1 score (NOT accuracy!)
    if final_f1 > best_fold_f1:
        best_fold_f1 = final_f1
        best_state = best_fold_state
        print(f"    🏆 New best overall model! (F1: {final_f1:.4f})")

    print(f"\nFold {fold} Best Results (from epoch {best_epoch}):")
    print(f"  Overall Accuracy: {te_acc_final:.4f}")
    print(f"  Overall F1 Score: {final_f1:.4f}")
    print(f"  Per-class Accuracy:")
    for i, (name, acc) in enumerate(zip(label_names, per_class_acc)):
        print(f"    {name}: {acc:.4f}")

print("\n" + "="*60)
print("Training Complete!")
print(f"Best F1 across all folds: {best_fold_f1:.4f}")
print("="*60)
# Out:
# Cross-validation: 5-fold
#
#
# ============================================================
#   Fold 1/5
# ============================================================
#   Training: 21 graphs -> 4569 after oversampling
# Epoch 001 | TrainLoss=0.1015 TrainAcc=0.2925 | TestLoss=0.1954 TestAcc=0.4639 | P=0.511 R=0.490 F1=0.408
# Epoch 002 | TrainLoss=0.0859 TrainAcc=0.3047 | TestLoss=0.1952 TestAcc=0.4739 | P=0.443 R=0.479 F1=0.418
# Epoch 003 | TrainLoss=0.0773 TrainAcc=0.3355 | TestLoss=0.1733 TestAcc=0.4759 | P=0.487 R=0.556 F1=0.452
# Epoch 004 | TrainLoss=0.0672 TrainAcc=0.3629 | TestLoss=0.1652 TestAcc=0.4337 | P=0.473 R=0.537 F1=0.426
# Epoch 005 | TrainLoss=0.0610 TrainAcc=0.3762 | TestLoss=0.2210 TestAcc=0.3153 | P=0.469 R=0.503 F1=0.340
# Epoch 006 | TrainLoss=0.0532 TrainAcc=0.3878 | TestLoss=0.3424 TestAcc=0.2932 | P=0.443 R=0.495 F1=0.324
# Epoch 007 | TrainLoss=0.0506 TrainAcc=0.3893 | TestLoss=0.2997 TestAcc=0.5080 | P=0.487 R=0.578 F1=0.479
# Epoch 008 | TrainLoss=0.0473 TrainAcc=0.3979 | TestLoss=0.4248 TestAcc=0.5422 | P=0.542 R=0.603 F1=0.527
# Epoch 009 | TrainLoss=0.0438 TrainAcc=0.4092 | TestLoss=0.5041 TestAcc=0.5382 | P=0.518 R=0.579 F1=0.507
# Epoch 010 | TrainLoss=0.0449 TrainAcc=0.4085 | TestLoss=0.4696 TestAcc=0.3333 | P=0.470 R=0.516 F1=0.380
# Epoch 020 | TrainLoss=0.0325 TrainAcc=0.4535 | TestLoss=0.4413 TestAcc=0.5120 | P=0.480 R=0.562 F1=0.469
# Epoch 030 | TrainLoss=0.0257 TrainAcc=0.4896 | TestLoss=0.5682 TestAcc=0.3394 | P=0.462 R=0.527 F1=0.373
# Epoch 040 | TrainLoss=0.0244 TrainAcc=0.5037 | TestLoss=0.5836 TestAcc=0.5542 | P=0.530 R=0.579 F1=0.513
# Epoch 050 | TrainLoss=0.0228 TrainAcc=0.5165 | TestLoss=0.5203 TestAcc=0.5763 | P=0.561 R=0.603 F1=0.542
# Epoch 060 | TrainLoss=0.0201 TrainAcc=0.5399 | TestLoss=0.6670 TestAcc=0.5803 | P=0.559 R=0.587 F1=0.539
# Epoch 070 | TrainLoss=0.0197 TrainAcc=0.5443 | TestLoss=0.7302 TestAcc=0.5964 | P=0.587 R=0.597 F1=0.558
# Epoch 080 | TrainLoss=0.0208 TrainAcc=0.5462 | TestLoss=0.6731 TestAcc=0.4679 | P=0.539 R=0.561 F1=0.495
# Epoch 090 | TrainLoss=0.0195 TrainAcc=0.5537 | TestLoss=0.6533 TestAcc=0.3675 | P=0.492 R=0.541 F1=0.425
# Epoch 100 | TrainLoss=0.0157 TrainAcc=0.5695 | TestLoss=0.8799 TestAcc=0.4277 | P=0.526 R=0.528 F1=0.465
# Epoch 110 | TrainLoss=0.0150 TrainAcc=0.5795 | TestLoss=0.7556 TestAcc=0.5161 | P=0.540 R=0.561 F1=0.509
# Epoch 120 | TrainLoss=0.0157 TrainAcc=0.5763 | TestLoss=0.8642 TestAcc=0.3855 | P=0.483 R=0.502 F1=0.435
# Epoch 130 | TrainLoss=0.0150 TrainAcc=0.5856 | TestLoss=0.7657 TestAcc=0.5984 | P=0.541 R=0.610 F1=0.551
# Epoch 140 | TrainLoss=0.0151 TrainAcc=0.5820 | TestLoss=0.8850 TestAcc=0.6024 | P=0.572 R=0.590 F1=0.553
# Epoch 150 | TrainLoss=0.0147 TrainAcc=0.5823 | TestLoss=0.8268 TestAcc=0.6124 | P=0.587 R=0.609 F1=0.567
# Epoch 160 | TrainLoss=0.0149 TrainAcc=0.5846 | TestLoss=0.8764 TestAcc=0.4779 | P=0.554 R=0.573 F1=0.505
# Epoch 170 | TrainLoss=0.0156 TrainAcc=0.5791 | TestLoss=0.8618 TestAcc=0.4056 | P=0.512 R=0.535 F1=0.448
# Epoch 180 | TrainLoss=0.0151 TrainAcc=0.5828 | TestLoss=0.9379 TestAcc=0.4880 | P=0.542 R=0.553 F1=0.493
# Epoch 190 | TrainLoss=0.0151 TrainAcc=0.5839 | TestLoss=0.9035 TestAcc=0.6064 | P=0.594 R=0.602 F1=0.560
# Epoch 200 | TrainLoss=0.0141 TrainAcc=0.5905 | TestLoss=0.9491 TestAcc=0.4217 | P=0.520 R=0.541 F1=0.462
# Epoch 210 | TrainLoss=0.0149 TrainAcc=0.5837 | TestLoss=0.9257 TestAcc=0.4759 | P=0.541 R=0.564 F1=0.493
# Epoch 220 | TrainLoss=0.0142 TrainAcc=0.5905 | TestLoss=0.9389 TestAcc=0.5361 | P=0.571 R=0.581 F1=0.527
# Epoch 230 | TrainLoss=0.0137 TrainAcc=0.5904 | TestLoss=0.9966 TestAcc=0.5462 | P=0.562 R=0.587 F1=0.531
# Epoch 240 | TrainLoss=0.0138 TrainAcc=0.5872 | TestLoss=0.9324 TestAcc=0.5341 | P=0.557 R=0.580 F1=0.523
# Epoch 250 | TrainLoss=0.0141 TrainAcc=0.5868 | TestLoss=0.9208 TestAcc=0.4618 | P=0.528 R=0.550 F1=0.481
# Epoch 260 | TrainLoss=0.0131 TrainAcc=0.5932 | TestLoss=0.9689 TestAcc=0.3936 | P=0.498 R=0.531 F1=0.440
# Epoch 270 | TrainLoss=0.0131 TrainAcc=0.5884 | TestLoss=0.9586 TestAcc=0.5382 | P=0.567 R=0.584 F1=0.531
# Epoch 280 | TrainLoss=0.0150 TrainAcc=0.5863 | TestLoss=0.9213 TestAcc=0.5361 | P=0.556 R=0.589 F1=0.532
# Epoch 290 | TrainLoss=0.0139 TrainAcc=0.5899 | TestLoss=0.9457 TestAcc=0.4639 | P=0.546 R=0.572 F1=0.497
# Epoch 300 | TrainLoss=0.0139 TrainAcc=0.5899 | TestLoss=0.9402 TestAcc=0.5422 | P=0.559 R=0.583 F1=0.527
# Epoch 310 | TrainLoss=0.0131 TrainAcc=0.5956 | TestLoss=0.9713 TestAcc=0.5442 | P=0.560 R=0.584 F1=0.529
# Epoch 320 | TrainLoss=0.0129 TrainAcc=0.5898 | TestLoss=0.9794 TestAcc=0.4659 | P=0.552 R=0.560 F1=0.490
# Epoch 330 | TrainLoss=0.0140 TrainAcc=0.5920 | TestLoss=0.9570 TestAcc=0.4699 | P=0.539 R=0.562 F1=0.489
# Epoch 340 | TrainLoss=0.0131 TrainAcc=0.5930 | TestLoss=0.9715 TestAcc=0.5341 | P=0.556 R=0.580 F1=0.523
# Early stopping at epoch 341
# Fold 1 Final Test Accuracy: 0.4639
#
# ============================================================
#   Fold 2/5
# ============================================================
#   Training: 21 graphs -> 3265 after oversampling
# Epoch 001 | TrainLoss=0.1286 TrainAcc=0.2571 | TestLoss=0.1110 TestAcc=0.4083 | P=0.564 R=0.502 F1=0.316
# Epoch 002 | TrainLoss=0.1030 TrainAcc=0.2923 | TestLoss=0.1059 TestAcc=0.4155 | P=0.506 R=0.514 F1=0.331
# Epoch 003 | TrainLoss=0.0898 TrainAcc=0.3147 | TestLoss=0.0890 TestAcc=0.4478 | P=0.499 R=0.576 F1=0.384
# Epoch 004 | TrainLoss=0.0794 TrainAcc=0.3318 | TestLoss=0.0823 TestAcc=0.3291 | P=0.479 R=0.543 F1=0.326
# Epoch 005 | TrainLoss=0.0712 TrainAcc=0.3502 | TestLoss=0.0890 TestAcc=0.2176 | P=0.208 R=0.523 F1=0.247
# Epoch 006 | TrainLoss=0.0657 TrainAcc=0.3587 | TestLoss=0.0845 TestAcc=0.2338 | P=0.464 R=0.543 F1=0.269
# Epoch 007 | TrainLoss=0.0626 TrainAcc=0.3668 | TestLoss=0.0890 TestAcc=0.2860 | P=0.457 R=0.577 F1=0.310
# Epoch 008 | TrainLoss=0.0580 TrainAcc=0.3712 | TestLoss=0.1029 TestAcc=0.4460 | P=0.473 R=0.629 F1=0.431
# Epoch 009 | TrainLoss=0.0554 TrainAcc=0.3801 | TestLoss=0.0999 TestAcc=0.2590 | P=0.472 R=0.574 F1=0.300
# Epoch 010 | TrainLoss=0.0510 TrainAcc=0.3934 | TestLoss=0.1089 TestAcc=0.3022 | P=0.429 R=0.553 F1=0.331
# Epoch 020 | TrainLoss=0.0421 TrainAcc=0.4313 | TestLoss=0.1202 TestAcc=0.5378 | P=0.506 R=0.647 F1=0.511
# Epoch 030 | TrainLoss=0.0341 TrainAcc=0.4695 | TestLoss=0.1778 TestAcc=0.5216 | P=0.541 R=0.634 F1=0.523
# Epoch 040 | TrainLoss=0.0344 TrainAcc=0.4685 | TestLoss=0.1796 TestAcc=0.6529 | P=0.553 R=0.653 F1=0.577
# Epoch 050 | TrainLoss=0.0289 TrainAcc=0.4924 | TestLoss=0.1878 TestAcc=0.5899 | P=0.548 R=0.637 F1=0.554
# Epoch 060 | TrainLoss=0.0264 TrainAcc=0.5149 | TestLoss=0.1825 TestAcc=0.6007 | P=0.549 R=0.665 F1=0.567
# Epoch 070 | TrainLoss=0.0258 TrainAcc=0.5221 | TestLoss=0.2030 TestAcc=0.6187 | P=0.539 R=0.627 F1=0.553
# Epoch 080 | TrainLoss=0.0238 TrainAcc=0.5283 | TestLoss=0.2005 TestAcc=0.4496 | P=0.514 R=0.595 F1=0.484
# Epoch 090 | TrainLoss=0.0214 TrainAcc=0.5366 | TestLoss=0.2142 TestAcc=0.6277 | P=0.550 R=0.633 F1=0.564
# Epoch 100 | TrainLoss=0.0204 TrainAcc=0.5406 | TestLoss=0.1988 TestAcc=0.5270 | P=0.515 R=0.601 F1=0.502
# Epoch 110 | TrainLoss=0.0204 TrainAcc=0.5522 | TestLoss=0.1900 TestAcc=0.6871 | P=0.574 R=0.653 F1=0.596
# Epoch 120 | TrainLoss=0.0219 TrainAcc=0.5416 | TestLoss=0.1905 TestAcc=0.5252 | P=0.522 R=0.616 F1=0.512
# Epoch 130 | TrainLoss=0.0190 TrainAcc=0.5561 | TestLoss=0.2009 TestAcc=0.4496 | P=0.519 R=0.626 F1=0.489
# Epoch 140 | TrainLoss=0.0210 TrainAcc=0.5518 | TestLoss=0.2082 TestAcc=0.5629 | P=0.538 R=0.644 F1=0.546
# Epoch 150 | TrainLoss=0.0184 TrainAcc=0.5603 | TestLoss=0.2397 TestAcc=0.5701 | P=0.541 R=0.639 F1=0.546
# Epoch 160 | TrainLoss=0.0179 TrainAcc=0.5618 | TestLoss=0.2529 TestAcc=0.4910 | P=0.510 R=0.595 F1=0.493
# Epoch 170 | TrainLoss=0.0206 TrainAcc=0.5524 | TestLoss=0.2111 TestAcc=0.5719 | P=0.530 R=0.635 F1=0.540
# Epoch 180 | TrainLoss=0.0196 TrainAcc=0.5577 | TestLoss=0.2174 TestAcc=0.6133 | P=0.538 R=0.646 F1=0.560
# Epoch 190 | TrainLoss=0.0178 TrainAcc=0.5616 | TestLoss=0.2384 TestAcc=0.5665 | P=0.535 R=0.642 F1=0.545
# Epoch 200 | TrainLoss=0.0169 TrainAcc=0.5685 | TestLoss=0.2560 TestAcc=0.4568 | P=0.518 R=0.586 F1=0.489
# Epoch 210 | TrainLoss=0.0173 TrainAcc=0.5650 | TestLoss=0.2436 TestAcc=0.4478 | P=0.511 R=0.590 F1=0.475
# Epoch 220 | TrainLoss=0.0196 TrainAcc=0.5584 | TestLoss=0.2355 TestAcc=0.4514 | P=0.509 R=0.596 F1=0.482
# Epoch 230 | TrainLoss=0.0164 TrainAcc=0.5620 | TestLoss=0.2639 TestAcc=0.5126 | P=0.510 R=0.592 F1=0.501
# Epoch 240 | TrainLoss=0.0164 TrainAcc=0.5692 | TestLoss=0.2507 TestAcc=0.6403 | P=0.551 R=0.650 F1=0.575
# Epoch 250 | TrainLoss=0.0178 TrainAcc=0.5639 | TestLoss=0.2483 TestAcc=0.5647 | P=0.524 R=0.619 F1=0.533
# Epoch 260 | TrainLoss=0.0173 TrainAcc=0.5680 | TestLoss=0.2480 TestAcc=0.4478 | P=0.505 R=0.593 F1=0.477
# Epoch 270 | TrainLoss=0.0165 TrainAcc=0.5757 | TestLoss=0.2510 TestAcc=0.5198 | P=0.521 R=0.602 F1=0.511
# Epoch 280 | TrainLoss=0.0163 TrainAcc=0.5709 | TestLoss=0.2516 TestAcc=0.5234 | P=0.526 R=0.608 F1=0.517
# Early stopping at epoch 282
# Fold 2 Final Test Accuracy: 0.5845
#
# ============================================================
#   Fold 3/5
# ============================================================
#   Training: 22 graphs -> 3314 after oversampling
# Epoch 001 | TrainLoss=0.1315 TrainAcc=0.2592 | TestLoss=0.0870 TestAcc=0.3208 | P=0.510 R=0.503 F1=0.323
# Epoch 002 | TrainLoss=0.1059 TrainAcc=0.2986 | TestLoss=0.0985 TestAcc=0.4035 | P=0.440 R=0.471 F1=0.352
# Epoch 003 | TrainLoss=0.0940 TrainAcc=0.3194 | TestLoss=0.1015 TestAcc=0.4436 | P=0.440 R=0.480 F1=0.368
# Epoch 004 | TrainLoss=0.0838 TrainAcc=0.3482 | TestLoss=0.1072 TestAcc=0.3584 | P=0.410 R=0.494 F1=0.339
# Epoch 005 | TrainLoss=0.0744 TrainAcc=0.3768 | TestLoss=0.1138 TestAcc=0.6416 | P=0.436 R=0.544 F1=0.459
# Epoch 006 | TrainLoss=0.0689 TrainAcc=0.3908 | TestLoss=0.1463 TestAcc=0.1930 | P=0.380 R=0.477 F1=0.251
# Epoch 007 | TrainLoss=0.0675 TrainAcc=0.3898 | TestLoss=0.1488 TestAcc=0.6391 | P=0.447 R=0.553 F1=0.465
# Epoch 008 | TrainLoss=0.0628 TrainAcc=0.4004 | TestLoss=0.1598 TestAcc=0.5589 | P=0.433 R=0.552 F1=0.439
# Epoch 009 | TrainLoss=0.0582 TrainAcc=0.4022 | TestLoss=0.1369 TestAcc=0.1930 | P=0.423 R=0.477 F1=0.248
# Epoch 010 | TrainLoss=0.0550 TrainAcc=0.4086 | TestLoss=0.1476 TestAcc=0.2005 | P=0.419 R=0.460 F1=0.244
# Epoch 020 | TrainLoss=0.0424 TrainAcc=0.4392 | TestLoss=0.1648 TestAcc=0.3108 | P=0.443 R=0.555 F1=0.358
# Epoch 030 | TrainLoss=0.0347 TrainAcc=0.4668 | TestLoss=0.1670 TestAcc=0.6591 | P=0.466 R=0.601 F1=0.497
# Epoch 040 | TrainLoss=0.0340 TrainAcc=0.4780 | TestLoss=0.1453 TestAcc=0.6566 | P=0.456 R=0.586 F1=0.487
# Epoch 050 | TrainLoss=0.0305 TrainAcc=0.5019 | TestLoss=0.2050 TestAcc=0.4987 | P=0.448 R=0.559 F1=0.438
# Epoch 060 | TrainLoss=0.0261 TrainAcc=0.5214 | TestLoss=0.2526 TestAcc=0.5840 | P=0.453 R=0.557 F1=0.464
# Epoch 070 | TrainLoss=0.0245 TrainAcc=0.5291 | TestLoss=0.2653 TestAcc=0.3258 | P=0.439 R=0.541 F1=0.376
# Epoch 080 | TrainLoss=0.0255 TrainAcc=0.5347 | TestLoss=0.2517 TestAcc=0.6541 | P=0.448 R=0.552 F1=0.475
# Epoch 090 | TrainLoss=0.0239 TrainAcc=0.5421 | TestLoss=0.2448 TestAcc=0.2331 | P=0.418 R=0.554 F1=0.328
# Epoch 100 | TrainLoss=0.0219 TrainAcc=0.5624 | TestLoss=0.2650 TestAcc=0.3133 | P=0.428 R=0.529 F1=0.357
# Epoch 110 | TrainLoss=0.0215 TrainAcc=0.5633 | TestLoss=0.2980 TestAcc=0.6667 | P=0.465 R=0.579 F1=0.496
# Epoch 120 | TrainLoss=0.0193 TrainAcc=0.5704 | TestLoss=0.3633 TestAcc=0.6792 | P=0.484 R=0.584 F1=0.514
# Epoch 130 | TrainLoss=0.0211 TrainAcc=0.5637 | TestLoss=0.3652 TestAcc=0.6867 | P=0.490 R=0.573 F1=0.515
# Epoch 140 | TrainLoss=0.0200 TrainAcc=0.5713 | TestLoss=0.3277 TestAcc=0.6742 | P=0.471 R=0.573 F1=0.501
# Epoch 150 | TrainLoss=0.0203 TrainAcc=0.5710 | TestLoss=0.3035 TestAcc=0.6767 | P=0.477 R=0.583 F1=0.507
# Epoch 160 | TrainLoss=0.0215 TrainAcc=0.5658 | TestLoss=0.2725 TestAcc=0.6767 | P=0.479 R=0.597 F1=0.512
# Epoch 170 | TrainLoss=0.0209 TrainAcc=0.5664 | TestLoss=0.2887 TestAcc=0.6792 | P=0.475 R=0.575 F1=0.505
# Epoch 180 | TrainLoss=0.0204 TrainAcc=0.5773 | TestLoss=0.2831 TestAcc=0.6717 | P=0.463 R=0.568 F1=0.491
# Epoch 190 | TrainLoss=0.0180 TrainAcc=0.5853 | TestLoss=0.2994 TestAcc=0.6892 | P=0.496 R=0.596 F1=0.528
# Epoch 200 | TrainLoss=0.0173 TrainAcc=0.5922 | TestLoss=0.3139 TestAcc=0.6842 | P=0.476 R=0.572 F1=0.505
# Epoch 210 | TrainLoss=0.0190 TrainAcc=0.5795 | TestLoss=0.3087 TestAcc=0.6942 | P=0.497 R=0.584 F1=0.524
# Epoch 220 | TrainLoss=0.0181 TrainAcc=0.5840 | TestLoss=0.3719 TestAcc=0.6892 | P=0.493 R=0.554 F1=0.510
# Epoch 230 | TrainLoss=0.0190 TrainAcc=0.5850 | TestLoss=0.3307 TestAcc=0.6867 | P=0.485 R=0.549 F1=0.503
# Epoch 240 | TrainLoss=0.0192 TrainAcc=0.5814 | TestLoss=0.3225 TestAcc=0.6792 | P=0.466 R=0.550 F1=0.492
# Epoch 250 | TrainLoss=0.0179 TrainAcc=0.5880 | TestLoss=0.3162 TestAcc=0.6842 | P=0.476 R=0.566 F1=0.504
# Epoch 260 | TrainLoss=0.0178 TrainAcc=0.5885 | TestLoss=0.3600 TestAcc=0.6842 | P=0.478 R=0.543 F1=0.498
# Epoch 270 | TrainLoss=0.0171 TrainAcc=0.5930 | TestLoss=0.3528 TestAcc=0.6917 | P=0.491 R=0.573 F1=0.518
# Epoch 280 | TrainLoss=0.0169 TrainAcc=0.5892 | TestLoss=0.3480 TestAcc=0.6817 | P=0.467 R=0.543 F1=0.491
# Epoch 290 | TrainLoss=0.0193 TrainAcc=0.5795 | TestLoss=0.3294 TestAcc=0.6867 | P=0.476 R=0.549 F1=0.499
# Epoch 300 | TrainLoss=0.0192 TrainAcc=0.5804 | TestLoss=0.3214 TestAcc=0.6817 | P=0.467 R=0.543 F1=0.491
# Epoch 310 | TrainLoss=0.0184 TrainAcc=0.5822 | TestLoss=0.3340 TestAcc=0.5940 | P=0.452 R=0.531 F1=0.461
# Epoch 320 | TrainLoss=0.0168 TrainAcc=0.5925 | TestLoss=0.3240 TestAcc=0.6792 | P=0.463 R=0.542 F1=0.488
# Epoch 330 | TrainLoss=0.0181 TrainAcc=0.5857 | TestLoss=0.3160 TestAcc=0.6817 | P=0.466 R=0.547 F1=0.491
# Epoch 340 | TrainLoss=0.0183 TrainAcc=0.5836 | TestLoss=0.3237 TestAcc=0.6817 | P=0.466 R=0.547 F1=0.492
# Epoch 350 | TrainLoss=0.0162 TrainAcc=0.5965 | TestLoss=0.3219 TestAcc=0.5088 | P=0.448 R=0.520 F1=0.434
# Epoch 360 | TrainLoss=0.0173 TrainAcc=0.5929 | TestLoss=0.3210 TestAcc=0.5113 | P=0.451 R=0.525 F1=0.438
# Epoch 370 | TrainLoss=0.0174 TrainAcc=0.5913 | TestLoss=0.3109 TestAcc=0.6892 | P=0.473 R=0.554 F1=0.498
# Epoch 380 | TrainLoss=0.0199 TrainAcc=0.5790 | TestLoss=0.3065 TestAcc=0.6817 | P=0.464 R=0.551 F1=0.491
# Epoch 390 | TrainLoss=0.0200 TrainAcc=0.5790 | TestLoss=0.3068 TestAcc=0.6842 | P=0.467 R=0.552 F1=0.494
# Epoch 400 | TrainLoss=0.0171 TrainAcc=0.5942 | TestLoss=0.3138 TestAcc=0.6867 | P=0.471 R=0.553 F1=0.496
# Early stopping at epoch 405
# Fold 3 Final Test Accuracy: 0.6842
#
# ============================================================
#   Fold 4/5
# ============================================================
#   Training: 22 graphs -> 3608 after oversampling
# Epoch 001 | TrainLoss=0.1331 TrainAcc=0.2447 | TestLoss=0.1002 TestAcc=0.1509 | P=0.287 R=0.422 F1=0.168
# Epoch 002 | TrainLoss=0.1072 TrainAcc=0.2745 | TestLoss=0.0928 TestAcc=0.5259 | P=0.557 R=0.479 F1=0.340
# Epoch 003 | TrainLoss=0.0906 TrainAcc=0.3031 | TestLoss=0.0968 TestAcc=0.1415 | P=0.283 R=0.426 F1=0.176
# Epoch 004 | TrainLoss=0.0775 TrainAcc=0.3434 | TestLoss=0.0889 TestAcc=0.4127 | P=0.506 R=0.566 F1=0.345
# Epoch 005 | TrainLoss=0.0684 TrainAcc=0.3633 | TestLoss=0.0828 TestAcc=0.2075 | P=0.198 R=0.501 F1=0.242
# Epoch 006 | TrainLoss=0.0638 TrainAcc=0.3791 | TestLoss=0.0891 TestAcc=0.1934 | P=0.206 R=0.452 F1=0.241
# Epoch 007 | TrainLoss=0.0608 TrainAcc=0.3790 | TestLoss=0.0893 TestAcc=0.1745 | P=0.212 R=0.424 F1=0.225
# Epoch 008 | TrainLoss=0.0559 TrainAcc=0.3936 | TestLoss=0.0909 TestAcc=0.4528 | P=0.460 R=0.554 F1=0.403
# Epoch 009 | TrainLoss=0.0541 TrainAcc=0.4002 | TestLoss=0.0948 TestAcc=0.5212 | P=0.454 R=0.543 F1=0.419
# Epoch 010 | TrainLoss=0.0507 TrainAcc=0.4035 | TestLoss=0.0936 TestAcc=0.2099 | P=0.227 R=0.510 F1=0.263
# Epoch 020 | TrainLoss=0.0375 TrainAcc=0.4441 | TestLoss=0.1596 TestAcc=0.3656 | P=0.442 R=0.518 F1=0.348
# Epoch 030 | TrainLoss=0.0351 TrainAcc=0.4615 | TestLoss=0.1986 TestAcc=0.5708 | P=0.478 R=0.589 F1=0.461
# Epoch 040 | TrainLoss=0.0311 TrainAcc=0.4793 | TestLoss=0.2838 TestAcc=0.5519 | P=0.451 R=0.539 F1=0.431
# Epoch 050 | TrainLoss=0.0262 TrainAcc=0.5069 | TestLoss=0.2473 TestAcc=0.5000 | P=0.471 R=0.567 F1=0.432
# Epoch 060 | TrainLoss=0.0242 TrainAcc=0.5245 | TestLoss=0.2600 TestAcc=0.2311 | P=0.391 R=0.443 F1=0.251
# Epoch 070 | TrainLoss=0.0242 TrainAcc=0.5223 | TestLoss=0.2729 TestAcc=0.5825 | P=0.469 R=0.553 F1=0.458
# Epoch 080 | TrainLoss=0.0251 TrainAcc=0.5238 | TestLoss=0.2612 TestAcc=0.5590 | P=0.455 R=0.554 F1=0.442
# Epoch 090 | TrainLoss=0.0244 TrainAcc=0.5310 | TestLoss=0.2983 TestAcc=0.4929 | P=0.446 R=0.519 F1=0.408
# Epoch 100 | TrainLoss=0.0206 TrainAcc=0.5523 | TestLoss=0.2996 TestAcc=0.4009 | P=0.428 R=0.473 F1=0.354
# Epoch 110 | TrainLoss=0.0222 TrainAcc=0.5487 | TestLoss=0.3616 TestAcc=0.2406 | P=0.370 R=0.446 F1=0.257
# Epoch 120 | TrainLoss=0.0229 TrainAcc=0.5498 | TestLoss=0.3096 TestAcc=0.4009 | P=0.419 R=0.475 F1=0.354
# Epoch 130 | TrainLoss=0.0202 TrainAcc=0.5643 | TestLoss=0.3729 TestAcc=0.2193 | P=0.394 R=0.420 F1=0.246
# Epoch 140 | TrainLoss=0.0220 TrainAcc=0.5572 | TestLoss=0.2445 TestAcc=0.3231 | P=0.421 R=0.476 F1=0.314
# Epoch 150 | TrainLoss=0.0214 TrainAcc=0.5607 | TestLoss=0.3172 TestAcc=0.2453 | P=0.384 R=0.461 F1=0.263
# Epoch 160 | TrainLoss=0.0198 TrainAcc=0.5687 | TestLoss=0.3447 TestAcc=0.4198 | P=0.433 R=0.506 F1=0.373
# Epoch 170 | TrainLoss=0.0178 TrainAcc=0.5752 | TestLoss=0.3806 TestAcc=0.4151 | P=0.435 R=0.501 F1=0.369
# Epoch 180 | TrainLoss=0.0188 TrainAcc=0.5757 | TestLoss=0.3252 TestAcc=0.3160 | P=0.386 R=0.446 F1=0.299
# Epoch 190 | TrainLoss=0.0188 TrainAcc=0.5773 | TestLoss=0.3175 TestAcc=0.3962 | P=0.400 R=0.465 F1=0.341
# Epoch 200 | TrainLoss=0.0186 TrainAcc=0.5800 | TestLoss=0.3996 TestAcc=0.2382 | P=0.356 R=0.440 F1=0.248
# Epoch 210 | TrainLoss=0.0181 TrainAcc=0.5802 | TestLoss=0.4387 TestAcc=0.2429 | P=0.369 R=0.447 F1=0.253
# Epoch 220 | TrainLoss=0.0195 TrainAcc=0.5737 | TestLoss=0.4040 TestAcc=0.4104 | P=0.406 R=0.478 F1=0.354
# Epoch 230 | TrainLoss=0.0183 TrainAcc=0.5807 | TestLoss=0.4047 TestAcc=0.2382 | P=0.365 R=0.440 F1=0.247
# Epoch 240 | TrainLoss=0.0178 TrainAcc=0.5833 | TestLoss=0.3915 TestAcc=0.2382 | P=0.355 R=0.442 F1=0.249
# Epoch 250 | TrainLoss=0.0174 TrainAcc=0.5829 | TestLoss=0.4119 TestAcc=0.3208 | P=0.392 R=0.456 F1=0.303
# Epoch 260 | TrainLoss=0.0199 TrainAcc=0.5760 | TestLoss=0.4167 TestAcc=0.3986 | P=0.399 R=0.468 F1=0.343
# Early stopping at epoch 269
# Fold 4 Final Test Accuracy: 0.2406
#
# ============================================================
#   Fold 5/5
# ============================================================
#   Training: 22 graphs -> 3084 after oversampling
# Epoch 001 | TrainLoss=0.1372 TrainAcc=0.2514 | TestLoss=0.0894 TestAcc=0.4406 | P=0.541 R=0.510 F1=0.307
# Epoch 002 | TrainLoss=0.1123 TrainAcc=0.2871 | TestLoss=0.0922 TestAcc=0.1133 | P=0.293 R=0.447 F1=0.128
# Epoch 003 | TrainLoss=0.1013 TrainAcc=0.2983 | TestLoss=0.0937 TestAcc=0.4424 | P=0.475 R=0.513 F1=0.327
# Epoch 004 | TrainLoss=0.0885 TrainAcc=0.3231 | TestLoss=0.0994 TestAcc=0.2194 | P=0.441 R=0.525 F1=0.248
# Epoch 005 | TrainLoss=0.0835 TrainAcc=0.3376 | TestLoss=0.0942 TestAcc=0.2338 | P=0.430 R=0.509 F1=0.250
# Epoch 006 | TrainLoss=0.0761 TrainAcc=0.3630 | TestLoss=0.1014 TestAcc=0.4371 | P=0.461 R=0.555 F1=0.361
# Epoch 007 | TrainLoss=0.0691 TrainAcc=0.3729 | TestLoss=0.1152 TestAcc=0.4928 | P=0.428 R=0.562 F1=0.382
# Epoch 008 | TrainLoss=0.0651 TrainAcc=0.3817 | TestLoss=0.1157 TestAcc=0.2014 | P=0.442 R=0.513 F1=0.244
# Epoch 009 | TrainLoss=0.0658 TrainAcc=0.3758 | TestLoss=0.1330 TestAcc=0.4478 | P=0.405 R=0.529 F1=0.364
# Epoch 010 | TrainLoss=0.0587 TrainAcc=0.3965 | TestLoss=0.1412 TestAcc=0.1871 | P=0.403 R=0.478 F1=0.213
# Epoch 020 | TrainLoss=0.0480 TrainAcc=0.4216 | TestLoss=0.1461 TestAcc=0.3363 | P=0.409 R=0.489 F1=0.318
# Epoch 030 | TrainLoss=0.0350 TrainAcc=0.4608 | TestLoss=0.2111 TestAcc=0.2338 | P=0.362 R=0.432 F1=0.231
# Epoch 040 | TrainLoss=0.0336 TrainAcc=0.4751 | TestLoss=0.2188 TestAcc=0.5414 | P=0.407 R=0.491 F1=0.392
# Epoch 050 | TrainLoss=0.0291 TrainAcc=0.4943 | TestLoss=0.1888 TestAcc=0.5647 | P=0.440 R=0.529 F1=0.432
# Epoch 060 | TrainLoss=0.0246 TrainAcc=0.5160 | TestLoss=0.2766 TestAcc=0.2734 | P=0.416 R=0.474 F1=0.280
# Epoch 070 | TrainLoss=0.0260 TrainAcc=0.5153 | TestLoss=0.2312 TestAcc=0.5863 | P=0.433 R=0.512 F1=0.431
# Epoch 080 | TrainLoss=0.0250 TrainAcc=0.5182 | TestLoss=0.2155 TestAcc=0.6097 | P=0.437 R=0.508 F1=0.435
# Epoch 090 | TrainLoss=0.0259 TrainAcc=0.5211 | TestLoss=0.2331 TestAcc=0.5701 | P=0.455 R=0.528 F1=0.440
# Epoch 100 | TrainLoss=0.0241 TrainAcc=0.5305 | TestLoss=0.2089 TestAcc=0.5324 | P=0.450 R=0.526 F1=0.434
# Epoch 110 | TrainLoss=0.0233 TrainAcc=0.5342 | TestLoss=0.2221 TestAcc=0.2788 | P=0.392 R=0.457 F1=0.298
# Epoch 120 | TrainLoss=0.0206 TrainAcc=0.5443 | TestLoss=0.2565 TestAcc=0.6079 | P=0.447 R=0.515 F1=0.447
# Epoch 130 | TrainLoss=0.0216 TrainAcc=0.5482 | TestLoss=0.2615 TestAcc=0.6133 | P=0.450 R=0.519 F1=0.450
# Epoch 140 | TrainLoss=0.0244 TrainAcc=0.5442 | TestLoss=0.2243 TestAcc=0.4748 | P=0.435 R=0.501 F1=0.396
# Epoch 150 | TrainLoss=0.0209 TrainAcc=0.5505 | TestLoss=0.2519 TestAcc=0.6061 | P=0.448 R=0.512 F1=0.446
# Epoch 160 | TrainLoss=0.0211 TrainAcc=0.5566 | TestLoss=0.2357 TestAcc=0.6007 | P=0.439 R=0.502 F1=0.437
# Epoch 170 | TrainLoss=0.0204 TrainAcc=0.5551 | TestLoss=0.2337 TestAcc=0.6187 | P=0.462 R=0.527 F1=0.461
# Epoch 180 | TrainLoss=0.0192 TrainAcc=0.5623 | TestLoss=0.2095 TestAcc=0.6187 | P=0.451 R=0.519 F1=0.451
# Epoch 190 | TrainLoss=0.0182 TrainAcc=0.5660 | TestLoss=0.2509 TestAcc=0.6169 | P=0.460 R=0.529 F1=0.459
# Epoch 200 | TrainLoss=0.0196 TrainAcc=0.5580 | TestLoss=0.2398 TestAcc=0.6169 | P=0.459 R=0.525 F1=0.458
# Epoch 210 | TrainLoss=0.0193 TrainAcc=0.5611 | TestLoss=0.2473 TestAcc=0.3687 | P=0.442 R=0.503 F1=0.356
# Epoch 220 | TrainLoss=0.0190 TrainAcc=0.5618 | TestLoss=0.2474 TestAcc=0.6169 | P=0.460 R=0.529 F1=0.459
# Epoch 230 | TrainLoss=0.0198 TrainAcc=0.5603 | TestLoss=0.2349 TestAcc=0.6205 | P=0.459 R=0.528 F1=0.459
# Epoch 240 | TrainLoss=0.0198 TrainAcc=0.5599 | TestLoss=0.2545 TestAcc=0.6133 | P=0.456 R=0.525 F1=0.455
# Epoch 250 | TrainLoss=0.0185 TrainAcc=0.5685 | TestLoss=0.2525 TestAcc=0.5612 | P=0.448 R=0.514 F1=0.434
# Epoch 260 | TrainLoss=0.0195 TrainAcc=0.5614 | TestLoss=0.2333 TestAcc=0.5540 | P=0.455 R=0.522 F1=0.437
# Epoch 270 | TrainLoss=0.0188 TrainAcc=0.5680 | TestLoss=0.2389 TestAcc=0.6295 | P=0.465 R=0.540 F1=0.467
# Epoch 280 | TrainLoss=0.0190 TrainAcc=0.5675 | TestLoss=0.2370 TestAcc=0.5629 | P=0.459 R=0.523 F1=0.441
# Epoch 290 | TrainLoss=0.0197 TrainAcc=0.5612 | TestLoss=0.2433 TestAcc=0.3076 | P=0.425 R=0.484 F1=0.318
# Epoch 300 | TrainLoss=0.0191 TrainAcc=0.5682 | TestLoss=0.2483 TestAcc=0.5629 | P=0.457 R=0.523 F1=0.441
# Epoch 310 | TrainLoss=0.0169 TrainAcc=0.5758 | TestLoss=0.2544 TestAcc=0.6223 | P=0.459 R=0.528 F1=0.460
# Epoch 320 | TrainLoss=0.0186 TrainAcc=0.5675 | TestLoss=0.2512 TestAcc=0.3813 | P=0.444 R=0.501 F1=0.363
# Epoch 330 | TrainLoss=0.0184 TrainAcc=0.5657 | TestLoss=0.2490 TestAcc=0.5665 | P=0.461 R=0.526 F1=0.444
# Epoch 340 | TrainLoss=0.0178 TrainAcc=0.5717 | TestLoss=0.2471 TestAcc=0.6277 | P=0.464 R=0.532 F1=0.465
# Epoch 350 | TrainLoss=0.0204 TrainAcc=0.5583 | TestLoss=0.2423 TestAcc=0.4371 | P=0.446 R=0.505 F1=0.388
# Epoch 360 | TrainLoss=0.0165 TrainAcc=0.5751 | TestLoss=0.2538 TestAcc=0.3129 | P=0.432 R=0.488 F1=0.326
# Epoch 370 | TrainLoss=0.0172 TrainAcc=0.5699 | TestLoss=0.2583 TestAcc=0.4424 | P=0.449 R=0.509 F1=0.392
# Epoch 380 | TrainLoss=0.0178 TrainAcc=0.5696 | TestLoss=0.2576 TestAcc=0.5629 | P=0.456 R=0.523 F1=0.440
# Epoch 390 | TrainLoss=0.0200 TrainAcc=0.5590 | TestLoss=0.2536 TestAcc=0.4371 | P=0.448 R=0.507 F1=0.389
# Epoch 400 | TrainLoss=0.0191 TrainAcc=0.5649 | TestLoss=0.2542 TestAcc=0.4371 | P=0.448 R=0.507 F1=0.389
# Epoch 410 | TrainLoss=0.0187 TrainAcc=0.5683 | TestLoss=0.2557 TestAcc=0.5612 | P=0.457 R=0.524 F1=0.440
# Epoch 420 | TrainLoss=0.0175 TrainAcc=0.5685 | TestLoss=0.2580 TestAcc=0.4982 | P=0.452 R=0.516 F1=0.415
# Epoch 430 | TrainLoss=0.0182 TrainAcc=0.5682 | TestLoss=0.2576 TestAcc=0.4964 | P=0.450 R=0.513 F1=0.414
# Epoch 440 | TrainLoss=0.0187 TrainAcc=0.5693 | TestLoss=0.2543 TestAcc=0.4317 | P=0.442 R=0.501 F1=0.384
# Epoch 450 | TrainLoss=0.0177 TrainAcc=0.5704 | TestLoss=0.2555 TestAcc=0.5594 | P=0.452 R=0.520 F1=0.436
# Epoch 460 | TrainLoss=0.0181 TrainAcc=0.5686 | TestLoss=0.2532 TestAcc=0.5594 | P=0.456 R=0.522 F1=0.438
# Epoch 470 | TrainLoss=0.0184 TrainAcc=0.5676 | TestLoss=0.2505 TestAcc=0.5612 | P=0.456 R=0.522 F1=0.439
# Epoch 480 | TrainLoss=0.0199 TrainAcc=0.5670 | TestLoss=0.2532 TestAcc=0.5594 | P=0.456 R=0.522 F1=0.438
# Epoch 490 | TrainLoss=0.0170 TrainAcc=0.5737 | TestLoss=0.2544 TestAcc=0.5612 | P=0.456 R=0.522 F1=0.439
# Epoch 500 | TrainLoss=0.0178 TrainAcc=0.5700 | TestLoss=0.2542 TestAcc=0.5612 | P=0.456 R=0.522 F1=0.439
# Epoch 510 | TrainLoss=0.0198 TrainAcc=0.5646 | TestLoss=0.2537 TestAcc=0.4964 | P=0.450 R=0.513 F1=0.414
# Epoch 520 | TrainLoss=0.0185 TrainAcc=0.5695 | TestLoss=0.2524 TestAcc=0.5594 | P=0.456 R=0.522 F1=0.438
# Epoch 530 | TrainLoss=0.0174 TrainAcc=0.5745 | TestLoss=0.2531 TestAcc=0.6223 | P=0.463 R=0.531 F1=0.462
# Early stopping at epoch 539
# Fold 5 Final Test Accuracy: 0.5594
#
# ============================================================
# Training Complete!
# ============================================================

# %% [markdown]
# ## Results and Model Saving

# %%
# Cross-validation summary
fold_accuracies = np.array(fold_accuracies)
fold_f1_scores = np.array(fold_f1_scores)

print(f"\nFold Results:")
for i, (acc, f1) in enumerate(zip(fold_accuracies, fold_f1_scores), start=1):
    print(f"  Fold {i}: Accuracy={acc:.4f}, F1={f1:.4f}")

print(f"\nMean Accuracy: {fold_accuracies.mean():.4f} ± {fold_accuracies.std():.4f}")
print(f"Mean F1 Score: {fold_f1_scores.mean():.4f} ± {fold_f1_scores.std():.4f}")
print(f"\nBest F1 Score: {best_fold_f1:.4f}")
# Out:
# Fold Accuracies:
#   Fold 1: 0.4639
#   Fold 2: 0.5845
#   Fold 3: 0.6842
#   Fold 4: 0.2406
#   Fold 5: 0.5594
#
# Mean Accuracy: 0.5065 ± 0.1503
# Best Fold Accuracy: 0.6842

# %%
# Save best model
best_model = ImprovedGATModel(
    input_dim=input_dim, hidden_dim=128, num_heads=8,
    num_classes=output_dim, dropout=0.3
).to(device)
best_model.load_state_dict(best_state)

pth_path = os.path.join(OUTPUT_DIR, "trained_model.pth")
torch.save({
    "model_state_dict": best_model.state_dict(),
    "input_dim": input_dim,
    "output_dim": output_dim,
    "best_fold_acc": best_fold_acc,
    "cv_mean_acc": fold_accuracies.mean(),
    "cv_std_acc": fold_accuracies.std(),
    "label_names": label_names,
    "class_counts": class_counts,
}, pth_path)

print(f"\n✓ Model saved to: {pth_path}")
# Out:
# ✓ Model saved to: /content/output_local/trained_model.pth

# %%
# Overall metrics
all_y_true = np.array(all_y_true)
all_y_pred = np.array(all_y_pred)

precision, recall, f1, support = precision_recall_fscore_support(
    all_y_true, all_y_pred, labels=range(output_dim), zero_division=0
)

metrics_df = pd.DataFrame({
    "Class": label_names,
    "Precision": precision,
    "Recall": recall,
    "F1-Score": f1,
    "Support": support
})

metrics_csv = os.path.join(OUTPUT_DIR, "per_class_metrics.csv")
metrics_df.to_csv(metrics_csv, index=False)
print(f"\n✓ Metrics saved to: {metrics_csv}")
print(f"\n{metrics_df.to_string(index=False)}")
# Out:
# ✓ Metrics saved to: /content/output_local/per_class_metrics.csv
#
#         Class  Precision   Recall  F1-Score  Support
# No Annotation   0.860000 0.439567  0.581775     1663
#     Dimension   0.537341 0.784574  0.637838      376
#          Text   0.195202 0.598662  0.294408      299
#          Both   0.316239 0.389474  0.349057       95

# %%
# Overall confusion matrix
cm = confusion_matrix(all_y_true, all_y_pred, labels=range(output_dim))
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_names, yticklabels=label_names)
plt.title("Overall Confusion Matrix (All Folds)")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_DIR, "confusion_matrix_overall.png"))
plt.show()

print(f"\n✓ All results saved to: {OUTPUT_DIR}/")
# Out:
# ✓ All results saved to: /content/output_local/

# %%
# Overall class accuracies histogram
print("\n📊 Generating overall class accuracies...")
plot_class_accuracies(
    all_y_true, all_y_pred, label_names,
    os.path.join(OUTPUT_DIR, "class_accuracies_overall.png")
)

print(f"\n✅ All visualizations complete!")
print(f"✅ Check your Google Drive: {OUTPUT_DIR}/")
# Out:
# 📊 Generating overall class accuracies...
# ✅ All visualizations complete!
# ✅ Check your Google Drive: /content/output_local/

# %%
# Copy results back to Google Drive
print(f"\n📤 Copying results back to Google Drive...")
if os.path.exists(LOCAL_OUTPUT):
    # Copy entire output directory to Drive
    if os.path.exists(DRIVE_OUTPUT):
        shutil.rmtree(DRIVE_OUTPUT)
    shutil.copytree(LOCAL_OUTPUT, DRIVE_OUTPUT)
    print(f"✓ Results copied to: {DRIVE_OUTPUT}")
    print(f"\n🎉 Training complete! All results saved to Google Drive.")
else:
    print(f"⚠ No local output found at {LOCAL_OUTPUT}")
# Out:
# 📤 Copying results back to Google Drive...
# ✓ Results copied to: /content/drive/MyDrive/Spatial GNN/model/5.OutputML_GAT_4CLASS
#
# 🎉 Training complete! All results saved to Google Drive.
